# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = np.linspace(0,30,20)
data1
# Out:
# array([ 0.        ,  1.57894737,  3.15789474,  4.73684211,  6.31578947,
#         7.89473684,  9.47368421, 11.05263158, 12.63157895, 14.21052632,
#        15.78947368, 17.36842105, 18.94736842, 20.52631579, 22.10526316,
#        23.68421053, 25.26315789, 26.84210526, 28.42105263, 30.        ])

# %%
data2 = data1 ** 2/5

# %%
my_fig, my_axes = plt.subplots()
my_axes.plot(data1, data2, color="#1E0703", alpha=0.5)
my_axes.plot(data2, data1)
plt.show()

# %%
(new_fig, new_axes) = plt.subplots()
new_axes.plot(data1, data1 + 2, color = "blue", linewidth=1.0)
new_axes.plot(data1, data1 + 4, color = "green", linewidth=3.0)
new_axes.plot(data1, data1 + 6, color = "#000000", linestyle="--", marker="o", markersize=5, markerfacecolor="red")
new_axes.plot(data1, data1 + 10, color = "#000000", linestyle="--", marker="+", markersize=8, markerfacecolor="red")
plt.show()

# %%
#scatter

# %%
plt.scatter(data1, data2)
plt.show()

# %%
plt.hist(data1, data2)
plt.show()

# %%
new_arr = np.random.randint(0,100,20)
new_arr
# Out:
# array([11, 22, 62, 73, 96, 24, 55, 53, 41, 34, 40, 79, 78, 98,  5, 59, 81,
#        96, 40, 68])

# %%
plt.boxplot(new_arr)
plt.show()

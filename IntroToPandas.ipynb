# %%
import numpy as np
import pandas as pd

# %%
grades = {"Gorkem": 90, "ayarlicazhocam": 85, "tamamdır": 20}

# %%
pd.Series(grades)
# Out:
# Gorkem            90
# ayarlicazhocam    85
# tamamdır          20
# dtype: int64

# %%
names = ["Gorkem", "ayarlicazhocam", "tamamdır"]
nots = [90, 85, 20]

# %%
pd.Series(nots, names)
# Out:
# Gorkem            90
# ayarlicazhocam    85
# tamamdır          20
# dtype: int64

# %%
contest_result = pd.Series(data=[90, 85, 20], index=["Gorkem", "ayarlicazhocam", "tamamdır"])

# %%
contest_result["Gorkem"]
# Out:
# np.int64(90)
